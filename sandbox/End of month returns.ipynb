# %%
from pandas_datareader import data
import numpy as np 
import scipy as sp 
import pandas as pd 
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
pd.set_option('display.notebook_repr_html', True)

from datetime import date, datetime, timedelta
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline 
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set(rc={"figure.figsize": (20, 10)})  

from cryptocompare import get_daily_trade_hist
from indicators import *

import requests
import talib
import plot

# %%
prices = get_daily_trade_hist('BTC')[datetime(2018,1,1):]

# %%
ax = prices.close.plot()
ymin, ymax = ax.get_ybound()
ax.fill_between(prices.index, ymin, ymax, where=prices.index.day>20, alpha=.2, color='orange')

# %%
prices['returns'] = prices.close.pct_change(5)
prices.groupby(prices.index.day // 5 * 5).returns.mean()
# Out:
# time
# 0    -0.014752
# 5    -0.030092
# 10   -0.045040
# 15    0.022293
# 20    0.020551
# 25   -0.012196
# 30   -0.040972
# Name: returns, dtype: float64
