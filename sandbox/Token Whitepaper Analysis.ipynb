# %% [markdown]
# # Overview
#
# This is an effort to programatically analyze token whitepapers through a simple annotation framework using the tagging feature of the [hypothes.is](https://hypothes.is).
#
# I confine the vocabulary to include the most salient concepts within the abstract and conclusion, with the assumption that crux the authors' arguments are summarized in these sections.
#
# Each concept is highlighted and tagged with the label *concept*. We can then use the manual tagging to algorithmically generate tagging of this concept's appearance throughout the other sections of the document as well as within other documents. This cross document annotation should reveal similarities, differences and links between the constraints and solutions addressed in each paper.

# %%
from IPython.display import IFrame
from hypothesis import HypothesisApi
from pandas.io.json import json_normalize
import re
import os
import requests
import pandas as pd
import textract

# %% [markdown]
# ## Contents
# - [Get annotations](#Get-annotations)
# - [Normalize annotation data](#Normalize-annotation-data)
# - Analysis
#  - [Abstract](#Abstract)
#  - [Body](#Body)
#  - [Conclusion](#Conclusion)
# - [Update annotations](#Update-annotations)

# %% [markdown]
# ### Get annotations
#
# I've created a simple wrapper for the [hypothes.is API](https://h.readthedocs.io/en/latest/api-reference/). We use this class to get all the annotations on the bitcoin whitepaper, first confining our search to the group *Token Whitepapers* and then to those that have *bitcoin* in the file name.

# %%
hypothesis = HypothesisApi()

hypothesis.search_by_group_name(
    'Token Whitepapers', 
    params={
        'limit': 200,
        'uri.parts': 'bitcoin'
    }
)
# Out:
# [{'updated': '2019-02-05T18:24:49.608813+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 1280, 'start': 1275},
#      {'exact': 'proof',
#       'prefix': '  longestproof-of-work chain as ',
#       'type': 'TextQuoteSelector',
#       'suffix': ' of what happened while they wer'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/UrMJWilzEemJkTc4McKOYw',
#    'html': 'https://hypothes.is/a/UrMJWilzEemJkTc4McKOYw',
#    'incontext': 'https://hyp.is/UrMJWilzEemJkTc4McKOYw/bitcoin.org/bitcoin.pdf'},
#   'tags': ['requirement'],
#   'text': '',
#   'created': '2019-02-05T18:24:49.608813+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'UrMJWilzEemJkTc4McKOYw',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:24:29.358457+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 1195, 'start': 1188},
#      {'exact': ' rejoin',
#       'prefix': 'nd   nodes   can   leave   and  ',
#       'type': 'TextQuoteSelector',
#       'suffix': '   the   network   at   will,   '}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/RpxYdClzEem8GcsPtIBiDQ',
#    'html': 'https://hypothes.is/a/RpxYdClzEem8GcsPtIBiDQ',
#    'incontext': 'https://hyp.is/RpxYdClzEem8GcsPtIBiDQ/bitcoin.org/bitcoin.pdf'},
#   'tags': ['requirement'],
#   'text': '',
#   'created': '2019-02-05T18:24:29.358457+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'RpxYdClzEem8GcsPtIBiDQ',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:24:17.525912+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 1180, 'start': 1175},
#      {'exact': 'leave',
#       'prefix': 'ortbasis,   and   nodes   can   ',
#       'type': 'TextQuoteSelector',
#       'suffix': '   and   rejoin   the   network '}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/P5zTqilzEemeIdsZZuqFSA',
#    'html': 'https://hypothes.is/a/P5zTqilzEemeIdsZZuqFSA',
#    'incontext': 'https://hyp.is/P5zTqilzEemeIdsZZuqFSA/bitcoin.org/bitcoin.pdf'},
#   'tags': ['requirement'],
#   'text': '',
#   'created': '2019-02-05T18:24:17.525912+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'P5zTqilzEemeIdsZZuqFSA',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:23:32.501955+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 1114, 'start': 1107},
#      {'exact': 'Message',
#       'prefix': 'f requires minimal structure.   ',
#       'type': 'TextQuoteSelector',
#       'suffix': 's are broadcast on a best effort'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/JMKhQClzEemkhq_VlIQedw',
#    'html': 'https://hypothes.is/a/JMKhQClzEemkhq_VlIQedw',
#    'incontext': 'https://hyp.is/JMKhQClzEemkhq_VlIQedw/bitcoin.org/bitcoin.pdf'},
#   'tags': ['requirement', 'solution'],
#   'text': '',
#   'created': '2019-02-05T18:23:32.501955+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'JMKhQClzEemkhq_VlIQedw',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:22:27.303829+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 1129, 'start': 1120},
#      {'exact': 'broadcast',
#       'prefix': 'nimal structure.   Messages are ',
#       'type': 'TextQuoteSelector',
#       'suffix': ' on a best effortbasis,   and   '}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/6swf7CluEemoEzdheYbNCA',
#    'html': 'https://hypothes.is/a/6swf7CluEemoEzdheYbNCA',
#    'incontext': 'https://hyp.is/6swf7CluEemoEzdheYbNCA/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution'],
#   'text': '',
#   'created': '2019-02-05T17:53:17.296892+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': '6swf7CluEemoEzdheYbNCA',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:18:43.048004+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 548, 'start': 541},
#      {'exact': 'network',
#       'prefix': 'ng problem using a peer-to-peer ',
#       'type': 'TextQuoteSelector',
#       'suffix': '.The   network   timestamps   tr'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/eE10CClyEemqxc-OkRxPJA',
#    'html': 'https://hypothes.is/a/eE10CClyEemqxc-OkRxPJA',
#    'incontext': 'https://hyp.is/eE10CClyEemqxc-OkRxPJA/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution', 'requirement'],
#   'text': '',
#   'created': '2019-02-05T18:18:43.048004+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'eE10CClyEemqxc-OkRxPJA',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:18:17.946155+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 979, 'start': 973},
#      {'exact': 'attack',
#       'prefix': 'odes that are not cooperating to',
#       'type': 'TextQuoteSelector',
#       'suffix': " the network,  they'll  generate"}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/3jet5iluEeml-YdeUcmiIw',
#    'html': 'https://hypothes.is/a/3jet5iluEeml-YdeUcmiIw',
#    'incontext': 'https://hyp.is/3jet5iluEeml-YdeUcmiIw/bitcoin.org/bitcoin.pdf'},
#   'tags': ['problem'],
#   'text': '',
#   'created': '2019-02-05T17:52:56.204407+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': '3jet5iluEeml-YdeUcmiIw',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:17:43.912546+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 944, 'start': 940},
#      {'exact': 'node',
#       'prefix': 'y of CPU power is controlled by ',
#       'type': 'TextQuoteSelector',
#       'suffix': 's that are not cooperating toatt'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/VSNUoilyEemgqIPxV4YmZw',
#    'html': 'https://hypothes.is/a/VSNUoilyEemgqIPxV4YmZw',
#    'incontext': 'https://hyp.is/VSNUoilyEemgqIPxV4YmZw/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution', 'requirement'],
#   'text': '',
#   'created': '2019-02-05T18:17:43.912546+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'VSNUoilyEemgqIPxV4YmZw',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:17:05.811052+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 910, 'start': 901},
#      {'exact': 'majority ',
#       'prefix': 'ool of CPU power.   Aslong as a ',
#       'type': 'TextQuoteSelector',
#       'suffix': 'of CPU power is controlled by no'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/1yvAoCluEemOXrOGRlaDcA',
#    'html': 'https://hypothes.is/a/1yvAoCluEemOXrOGRlaDcA',
#    'incontext': 'https://hyp.is/1yvAoCluEemOXrOGRlaDcA/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution', 'problem'],
#   'text': '',
#   'created': '2019-02-05T17:52:44.393258+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': '1yvAoCluEemOXrOGRlaDcA',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:16:47.465710+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 885, 'start': 876},
#      {'exact': 'CPU power',
#       'prefix': 't came from the largest pool of ',
#       'type': 'TextQuoteSelector',
#       'suffix': '.   Aslong as a majority of CPU '}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/M1MpLilyEemMW6c7OKWc7A',
#    'html': 'https://hypothes.is/a/M1MpLilyEemMW6c7OKWc7A',
#    'incontext': 'https://hyp.is/M1MpLilyEemMW6c7OKWc7A/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution'],
#   'text': '',
#   'created': '2019-02-05T18:16:47.465710+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'M1MpLilyEemMW6c7OKWc7A',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:16:09.993534+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 880, 'start': 876},
#      {'exact': 'CPU ',
#       'prefix': 't came from the largest pool of ',
#       'type': 'TextQuoteSelector',
#       'suffix': 'power.   Aslong as a majority of'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/HPZtWClyEemmAR_JDNga_A',
#    'html': 'https://hypothes.is/a/HPZtWClyEemmAR_JDNga_A',
#    'incontext': 'https://hyp.is/HPZtWClyEemmAR_JDNga_A/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution'],
#   'text': '',
#   'created': '2019-02-05T18:16:09.993534+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'HPZtWClyEemmAR_JDNga_A',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:15:29.484282+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 873, 'start': 868},
#      {'exact': 'pool ',
#       'prefix': 'f that it came from the largest ',
#       'type': 'TextQuoteSelector',
#       'suffix': 'of CPU power.   Aslong as a majo'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/yp1NLCluEemi7XsjqAsQDw',
#    'html': 'https://hypothes.is/a/yp1NLCluEemi7XsjqAsQDw',
#    'incontext': 'https://hyp.is/yp1NLCluEemi7XsjqAsQDw/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution'],
#   'text': '',
#   'created': '2019-02-05T17:52:23.333509+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'yp1NLCluEemi7XsjqAsQDw',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:15:06.621810+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 766, 'start': 752},
#      {'exact': ' longest chain',
#       'prefix': ' redoingthe proof-of-work.   The',
#       'type': 'TextQuoteSelector',
#       'suffix': ' not only serves as proof of the'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/vuxMlCluEemse7OquCmKZQ',
#    'html': 'https://hypothes.is/a/vuxMlCluEemse7OquCmKZQ',
#    'incontext': 'https://hyp.is/vuxMlCluEemse7OquCmKZQ/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution'],
#   'text': '',
#   'created': '2019-02-05T17:52:03.723743+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'vuxMlCluEemse7OquCmKZQ',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:14:43.384061+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 689, 'start': 683},
#      {'exact': 'record',
#       'prefix': '-based proof-of-work, forming a ',
#       'type': 'TextQuoteSelector',
#       'suffix': ' that cannot be changed without '}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/uleEZCluEemw9YeincTPxw',
#    'html': 'https://hypothes.is/a/uleEZCluEemw9YeincTPxw',
#    'incontext': 'https://hyp.is/uleEZCluEemw9YeincTPxw/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution'],
#   'text': '',
#   'created': '2019-02-05T17:51:56.014744+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'uleEZCluEemw9YeincTPxw',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:14:29.249462+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 671, 'start': 658},
#      {'exact': 'proof-of-work',
#       'prefix': ' ongoing   chain   ofhash-based ',
#       'type': 'TextQuoteSelector',
#       'suffix': ', forming a record that cannot b'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/srS_iCluEemN_8MpOeRvuw',
#    'html': 'https://hypothes.is/a/srS_iCluEemN_8MpOeRvuw',
#    'incontext': 'https://hyp.is/srS_iCluEemN_8MpOeRvuw/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution'],
#   'text': '',
#   'created': '2019-02-05T17:51:43.136588+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'srS_iCluEemN_8MpOeRvuw',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:14:15.796544+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 643, 'start': 637},
#      {'exact': 'chain ',
#       'prefix': '   them   into   an   ongoing   ',
#       'type': 'TextQuoteSelector',
#       'suffix': '  ofhash-based proof-of-work, fo'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/sH3IXiluEemNL-cOLpXXdA',
#    'html': 'https://hypothes.is/a/sH3IXiluEemNL-cOLpXXdA',
#    'incontext': 'https://hyp.is/sH3IXiluEemNL-cOLpXXdA/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution'],
#   'text': '',
#   'created': '2019-02-05T17:51:39.483797+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'sH3IXiluEemNL-cOLpXXdA',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:13:58.453629+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 602, 'start': 598},
#      {'exact': 'hash',
#       'prefix': 'imestamps   transactions   by   ',
#       'type': 'TextQuoteSelector',
#       'suffix': 'ing   them   into   an   ongoing'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/zpsKOClxEemdJtvXeYAbcA',
#    'html': 'https://hypothes.is/a/zpsKOClxEemdJtvXeYAbcA',
#    'incontext': 'https://hyp.is/zpsKOClxEemdJtvXeYAbcA/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution'],
#   'text': '',
#   'created': '2019-02-05T18:13:58.453629+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'zpsKOClxEemdJtvXeYAbcA',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:13:14.765275+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 589, 'start': 578},
#      {'exact': 'transaction',
#       'prefix': 'rk.The   network   timestamps   ',
#       'type': 'TextQuoteSelector',
#       'suffix': 's   by   hashing   them   into  '}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/tImN1ilxEem4ujdliG62dg',
#    'html': 'https://hypothes.is/a/tImN1ilxEem4ujdliG62dg',
#    'incontext': 'https://hyp.is/tImN1ilxEem4ujdliG62dg/bitcoin.org/bitcoin.pdf'},
#   'tags': ['requirement', 'problem'],
#   'text': '',
#   'created': '2019-02-05T18:13:14.765275+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'tImN1ilxEem4ujdliG62dg',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:11:44.185889+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 574, 'start': 564},
#      {'exact': ' timestamp',
#       'prefix': '-to-peer network.The   network  ',
#       'type': 'TextQuoteSelector',
#       'suffix': 's   transactions   by   hashing '}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/fopFBClxEemSjpP64P7xBw',
#    'html': 'https://hypothes.is/a/fopFBClxEemSjpP64P7xBw',
#    'incontext': 'https://hyp.is/fopFBClxEemSjpP64P7xBw/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution'],
#   'text': '',
#   'created': '2019-02-05T18:11:44.185889+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'fopFBClxEemSjpP64P7xBw',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:10:58.512961+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 463, 'start': 451},
#      {'exact': 'double-spend',
#       'prefix': 'ty is still required to prevent ',
#       'type': 'TextQuoteSelector',
#       'suffix': 'ing.We propose a solution to the'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/Y1ReyClxEemrKB_oA6DwCw',
#    'html': 'https://hypothes.is/a/Y1ReyClxEemrKB_oA6DwCw',
#    'incontext': 'https://hyp.is/Y1ReyClxEemrKB_oA6DwCw/bitcoin.org/bitcoin.pdf'},
#   'tags': ['problem'],
#   'text': '',
#   'created': '2019-02-05T18:10:58.512961+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'Y1ReyClxEemrKB_oA6DwCw',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:10:40.202279+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 421, 'start': 410},
#      {'exact': 'third party',
#       'prefix': 'nbenefits are lost if a trusted ',
#       'type': 'TextQuoteSelector',
#       'suffix': ' is still required to prevent do'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/WGyv2ClxEemIde_dsoThfA',
#    'html': 'https://hypothes.is/a/WGyv2ClxEemIde_dsoThfA',
#    'incontext': 'https://hyp.is/WGyv2ClxEemIde_dsoThfA/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution', 'problem'],
#   'text': '',
#   'created': '2019-02-05T18:10:40.202279+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'WGyv2ClxEemIde_dsoThfA',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:09:56.436680+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 407, 'start': 402},
#      {'exact': 'trust',
#       'prefix': ' the mainbenefits are lost if a ',
#       'type': 'TextQuoteSelector',
#       'suffix': 'ed third party is still required'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/MepW-ClxEemYcQOeSn1hPQ',
#    'html': 'https://hypothes.is/a/MepW-ClxEemYcQOeSn1hPQ',
#    'incontext': 'https://hyp.is/MepW-ClxEemYcQOeSn1hPQ/bitcoin.org/bitcoin.pdf'},
#   'tags': ['requirement'],
#   'text': '',
#   'created': '2019-02-05T18:09:35.632827+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'MepW-ClxEemYcQOeSn1hPQ',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:08:16.516233+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 336, 'start': 318},
#      {'exact': 'Digital signatures',
#       'prefix': 'ugh   afinancial institution.   ',
#       'type': 'TextQuoteSelector',
#       'suffix': ' provide part of the solution, b'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/YM2kFCluEemvQn-xWXtkaw',
#    'html': 'https://hypothes.is/a/YM2kFCluEemvQn-xWXtkaw',
#    'incontext': 'https://hyp.is/YM2kFCluEemvQn-xWXtkaw/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution'],
#   'text': '',
#   'created': '2019-02-05T17:49:25.725734+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'YM2kFCluEemvQn-xWXtkaw',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:08:04.567955+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 314, 'start': 293},
#      {'exact': 'financial institution',
#       'prefix': '   without   going   through   a',
#       'type': 'TextQuoteSelector',
#       'suffix': '.   Digital signatures provide p'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/Xc49oCluEemvv7ffXGZQlg',
#    'html': 'https://hypothes.is/a/Xc49oCluEemvv7ffXGZQlg',
#    'incontext': 'https://hyp.is/Xc49oCluEemvv7ffXGZQlg/bitcoin.org/bitcoin.pdf'},
#   'tags': ['problem'],
#   'text': '',
#   'created': '2019-02-05T17:49:20.671832+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'Xc49oCluEemvv7ffXGZQlg',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:07:38.302571+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 199, 'start': 183},
#      {'exact': 'onlinepayments  ',
#       'prefix': 'tronic   cash   would   allow   ',
#       'type': 'TextQuoteSelector',
#       'suffix': ' to   be   sent   directly   fro'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/WkiIeiluEemJDbtGQrEfUQ',
#    'html': 'https://hypothes.is/a/WkiIeiluEemJDbtGQrEfUQ',
#    'incontext': 'https://hyp.is/WkiIeiluEemJDbtGQrEfUQ/bitcoin.org/bitcoin.pdf'},
#   'tags': ['requirement'],
#   'text': 'online payments',
#   'created': '2019-02-05T17:49:14.722334+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'WkiIeiluEemJDbtGQrEfUQ',
#   'permissions': {'read': ['acct:malcolmjmr@hypothes.is'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:06:39.537195+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 166, 'start': 147},
#      {'exact': 'electronic   cash  ',
#       'prefix': '  peer-to-peer   version   of   ',
#       'type': 'TextQuoteSelector',
#       'suffix': ' would   allow   onlinepayments '}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/VslalCluEem3m3fBg7zA5Q',
#    'html': 'https://hypothes.is/a/VslalCluEem3m3fBg7zA5Q',
#    'incontext': 'https://hyp.is/VslalCluEem3m3fBg7zA5Q/bitcoin.org/bitcoin.pdf'},
#   'tags': ['requirement'],
#   'text': '',
#   'created': '2019-02-05T17:49:08.756061+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'VslalCluEem3m3fBg7zA5Q',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}},
#  {'updated': '2019-02-05T18:06:15.733820+00:00',
#   'group': 'LALjzxP7',
#   'target': [{'source': 'https://bitcoin.org/bitcoin.pdf',
#     'selector': [{'type': 'TextPositionSelector', 'end': 132, 'start': 117},
#      {'exact': 'peer-to-peer   ',
#       'prefix': 'coin.orgAbstract.   A  purely   ',
#       'type': 'TextQuoteSelector',
#       'suffix': 'version   of   electronic   cash'}]}],
#   'links': {'json': 'https://hypothes.is/api/annotations/UCR0OiluEemg1Kfi50P0vw',
#    'html': 'https://hypothes.is/a/UCR0OiluEemg1Kfi50P0vw',
#    'incontext': 'https://hyp.is/UCR0OiluEemg1Kfi50P0vw/bitcoin.org/bitcoin.pdf'},
#   'tags': ['solution'],
#   'text': '',
#   'created': '2019-02-05T17:48:57.626032+00:00',
#   'uri': 'https://bitcoin.org/bitcoin.pdf',
#   'flagged': False,
#   'user_info': {'display_name': None},
#   'moderation': {'flagCount': 0},
#   'user': 'acct:malcolmjmr@hypothes.is',
#   'hidden': False,
#   'document': {'title': ['bitcoin.pdf']},
#   'id': 'UCR0OiluEemg1Kfi50P0vw',
#   'permissions': {'read': ['group:LALjzxP7'],
#    'admin': ['acct:malcolmjmr@hypothes.is'],
#    'update': ['acct:malcolmjmr@hypothes.is'],
#    'delete': ['acct:malcolmjmr@hypothes.is']}}]

# %% [markdown]
# The result of our query is a list of annotations and their various details. The annotation objects are fairly hierarchal and require preprcessing to flatten and normalize the data.

# %%
hypothesis.previous_searches
# Out:
# [({'limit': 200, 'uri.parts': 'bitcoin', 'group': 'LALjzxP7'}, 27)]

# %% [markdown]
# ### Normalize Annotation Data

# %%
annotations = json_normalize(hypothesis.last_search_results)
for col in ['created','updated']:
    annotations[col] = pd.to_datetime(annotations[col])
    
annotations['concept'] = annotations.target.apply(lambda t: t[0]['selector'][1]['exact'].strip().lower())
annotations['tag'] = annotations.tags.apply(lambda t: ','.join(t))
annotations[['concept','tag']].sort_values('tag')
# Out:
#                   concept                   tag
# 23  financial institution               problem
# 6                  attack               problem
# 19           double-spend               problem
# 0                   proof           requirement
# 1                  rejoin           requirement
# 2                   leave           requirement
# 24         onlinepayments           requirement
# 21                  trust           requirement
# 25      electronic   cash           requirement
# 17            transaction   requirement,problem
# 3                 message  requirement,solution
# 22     digital signatures              solution
# 18              timestamp              solution
# 16                   hash              solution
# 15                  chain              solution
# 13                 record              solution
# 12          longest chain              solution
# 11                   pool              solution
# 10                    cpu              solution
# 9               cpu power              solution
# 4               broadcast              solution
# 14          proof-of-work              solution
# 26           peer-to-peer              solution
# 20            third party      solution,problem
# 8                majority      solution,problem
# 7                    node  solution,requirement
# 5                 network  solution,requirement

# %%
annotations['links.incontext'][0]
# Out:
# 'https://hyp.is/UrMJWilzEemJkTc4McKOYw/bitcoin.org/bitcoin.pdf'

# %%
DATA_DIR = 'tmp'

file_url = annotations['target'][0][0]['source']

def download(url):
    
    if not os.path.isdir(DATA_DIR):
        os.mkdir(DATA_DIR)
    
    filename = url.split('/')[-1]
    filepath = f'{DATA_DIR}/{filename}'
    
    if os.path.exists(filepath):
        print(f'File already downloaded: {filepath}')
        return filepath
    
    r = requests.get(url, stream=True)
    with open(filepath, 'wb') as f:
        f.write(r.content)
        print(f'Successfully saved file: {filepath}')
        return filepath

# %%
filename = download(file_url)
raw_text = textract.process(filename=filename).decode('utf-8').lower()
text = raw_text.replace(' \n',' ').replace('-\n',' ').replace('  ',' ')
# Out:
# File already downloaded: tmp/bitcoin.pdf

# %% [markdown]
# ### Abstract

# %%
abstract = raw_text.split('abstract. ')[1].split('\n\n')[0]
abstract
# Out:
# " a purely peer-to-peer version of electronic cash would allow online \npayments to be sent directly from one party to another without going through a \nfinancial institution.  digital signatures provide part of the solution, but the main \nbenefits are lost if a trusted third party is still required to prevent double-spending. \nwe propose a solution to the double-spending problem using a peer-to-peer network. \nthe network timestamps transactions by hashing them into an ongoing chain of \nhash-based proof-of-work, forming a record that cannot be changed without redoing \nthe proof-of-work.  the longest chain not only serves as proof of the sequence of \nevents witnessed, but proof that it came from the largest pool of cpu power.  as \nlong as a majority of cpu power is controlled by nodes that are not cooperating to \nattack the network, they'll generate the longest chain and outpace attackers.  the \nnetwork itself requires minimal structure.  messages are broadcast on a best effort \nbasis, and nodes can leave and rejoin the network at will, accepting the longest \nproof-of-work chain as proof of what happened while they were gone."

# %%
annotations.groupby('tag').concept.count()
# Out:
# tag
# problem                  3
# requirement              6
# requirement,problem      1
# requirement,solution     1
# solution                12
# solution,problem         2
# solution,requirement     2
# Name: concept, dtype: int64

# %%
annotations[annotations.tag.str.contains('requirement')].concept
# Out:
# 0                 proof
# 1                rejoin
# 2                 leave
# 3               message
# 5               network
# 7                  node
# 17          transaction
# 21                trust
# 24       onlinepayments
# 25    electronic   cash
# Name: concept, dtype: object

# %% [markdown]
# Trusted online payments with electronic cash. Nodes can message transaction to the network provide proof to other nodes whether they leave and rejoin (have a dedicated connection) to the network

# %%
annotations[annotations.tag.str.contains('problem')].concept
# Out:
# 6                    attack
# 8                  majority
# 17              transaction
# 19             double-spend
# 20              third party
# 23    financial institution
# Name: concept, dtype: object

# %% [markdown]
# All without the network getting attacked through double spend or majority. And without the need for third party financial instutions.

# %%
annotations[annotations.tag.str.contains('solution')].concept
# Out:
# 3                message
# 4              broadcast
# 5                network
# 7                   node
# 8               majority
# 9              cpu power
# 10                   cpu
# 11                  pool
# 12         longest chain
# 13                record
# 14         proof-of-work
# 15                 chain
# 16                  hash
# 18             timestamp
# 20           third party
# 22    digital signatures
# 26          peer-to-peer
# Name: concept, dtype: object

# %% [markdown]
# Node(s) broadcast message(s) with digital signiatures to peer to peer network. Node(s) create hash as proof of work (dedicated cpu power). Those with majority of pooled cpu power determine the record. They timestamp and hash (unique identifier) of message that is linked to chain hash. Longest chain is the one nodes trust.

# %% [markdown]
# ### Introduction

# %%
introduction = text.split('introduction')[1].split('\n\n')[1]
introduction
# Out:
# 'commerce on the internet has come to rely almost exclusively on financial institutions serving as trusted third parties to process electronic payments. while the system works well enough for most transactions, it still suffers from the inherent weaknesses of the trust based model. completely non-reversible transactions are not really possible, since financial institutions cannot avoid mediating disputes. the cost of mediation increases transaction costs, limiting the minimum practical transaction size and cutting off the possibility for small casual transactions, and there is a broader cost in the loss of ability to make non-reversible payments for non reversible services. with the possibility of reversal, the need for trust spreads. merchants must be wary of their customers, hassling them for more information than they would otherwise need. a certain percentage of fraud is accepted as unavoidable. these costs and payment uncertainties can be avoided in person by using physical currency, but no mechanism exists to make payments over a communications channel without a trusted party.\nwhat is needed is an electronic payment system based on cryptographic proof instead of trust, allowing any two willing parties to transact directly with each other without the need for a trusted third party. transactions that are computationally impractical to reverse would protect sellers from fraud, and routine escrow mechanisms could easily be implemented to protect buyers. in this paper, we propose a solution to the double-spending problem using a peer-to-peer distributed timestamp server to generate computational proof of the chronological order of transactions. the system is secure as long as honest nodes collectively control more cpu power than any cooperating group of attacker nodes.'

# %%
annotations['concept_freq_intro'] = annotations.concept.apply(lambda c: len(re.findall(c, introduction)))

# %% [markdown]
# ### Conclusion

# %%
conclusion = text.split('conclusion')[1].split('\n\n')[1]
conclusion
# Out:
# 'we have proposed a system for electronic transactions without relying on trust. we started with the usual framework of coins made from digital signatures, which provides strong control of ownership, but is incomplete without a way to prevent double-spending. to solve this, we proposed a peer-to-peer network using proof-of-work to record a public history of transactions that quickly becomes computationally impractical for an attacker to change if honest nodes control a majority of cpu power. the network is robust in its unstructured simplicity. nodes work all at once with little coordination. they do not need to be identified, since messages are not routed to any particular place and only need to be delivered on a best effort basis. nodes can leave and rejoin the network at will, accepting the proof-of-work chain as proof of what happened while they were gone. they vote with their cpu power, expressing their acceptance of valid blocks by working on extending them and rejecting invalid blocks by refusing to work on them. any needed rules and incentives can be enforced with this consensus mechanism.'

# %% [markdown]
# Todo:
# - Manually annotate conclusion

# %% [markdown]
# ### Body

# %%
body_start = re.search(introduction[-10:], text).end()
body_end = re.search(conclusion[10:], text).start()
body = text[body_start:body_end]

# %%
for section_name in ['abstract', 'introduction', 'body', 'conclusion']:
    col_name = f'concept_freq_{section_name}'
    section = locals()[section_name]
    annotations[col_name] = annotations.concept.apply(lambda c: len(re.findall(c, section)))
annotations['concept_freq_total'] = annotations.concept.apply(lambda c: len(re.findall(c, text)))

# %%
rel_cols = ['tag'] + [c for c in annotations.columns if 'concept' in c]
annotations[rel_cols].set_index('concept').sort_values('concept_freq_total', ascending=False)
# Out:
#                                         tag  concept_freq_abstract  \
# concept
# transaction             requirement,problem                      1
# hash                               solution                      2
# node                   solution,requirement                      2
# proof                           requirement                      6
# chain                              solution                      4
# attack                              problem                      2
# network                solution,requirement                      5
# proof-of-work                      solution                      3
# trust                           requirement                      1
# timestamp                          solution                      1
# cpu                                solution                      2
# majority                   solution,problem                      1
# cpu power                          solution                      2
# double-spend                        problem                      2
# peer-to-peer                       solution                      2
# broadcast                          solution                      1
# longest chain                      solution                      2
# third party                solution,problem                      1
# message                requirement,solution                      1
# digital signatures                 solution                      1
# financial institution               problem                      1
# rejoin                          requirement                      1
# leave                           requirement                      1
# record                             solution                      1
# pool                               solution                      1
# onlinepayments                  requirement                      0
# electronic   cash               requirement                      0
#
#                        concept_freq_introduction  concept_freq_body  \
# concept
# transaction                                    7                 59
# hash                                           0                 47
# node                                           2                 31
# proof                                          2                 16
# chain                                          0                 22
# attack                                         1                 21
# network                                        0                 13
# proof-of-work                                  0                 12
# trust                                          6                  5
# timestamp                                      1                 11
# cpu                                            1                  5
# majority                                       0                  5
# cpu power                                      1                  2
# double-spend                                   1                  2
# peer-to-peer                                   1                  1
# broadcast                                      0                  5
# longest chain                                  0                  3
# third party                                    1                  2
# message                                        0                  1
# digital signatures                             0                  1
# financial institution                          2                  0
# rejoin                                         0                  0
# leave                                          0                  0
# record                                         0                  0
# pool                                           0                  0
# onlinepayments                                 0                  0
# electronic   cash                              0                  0
#
#                        concept_freq_conclusion  concept_freq_total
# concept
# transaction                                  2                  69
# hash                                         0                  52
# node                                         3                  38
# proof                                        3                  27
# chain                                        1                  27
# attack                                       1                  25
# network                                      3                  21
# proof-of-work                                2                  17
# trust                                        1                  14
# timestamp                                    0                  14
# cpu                                          2                  10
# majority                                     1                   7
# cpu power                                    2                   7
# double-spend                                 1                   6
# peer-to-peer                                 1                   6
# broadcast                                    0                   6
# longest chain                                0                   5
# third party                                  0                   4
# message                                      1                   3
# digital signatures                           1                   3
# financial institution                        0                   3
# rejoin                                       1                   2
# leave                                        1                   2
# record                                       1                   2
# pool                                         0                   1
# onlinepayments                               0                   0
# electronic   cash                            0                   0

# %% [markdown]
# ### Update annotations
#
# Todo
# - add "bitcoin" and "concept" to annotations in abstract
# - download whitepaper pdf's to tmp folder
# - add annotations for each occurance in the rest of the document and other whitepapers
